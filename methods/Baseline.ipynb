# %% [markdown]
# # Training Resnet20 on CIFAR-10

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
import numpy as np
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
def swish(x):
    return x/(1+torch.exp(-x))

# %%
# define the Resnet20 mode;
class Resnet20(nn.Module):
    def __init__(self):
        super(Resnet20, self).__init__()
        self.conv0 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.batchnorm0 = nn.BatchNorm2d(16)
        
        self.conv1a = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1a = nn.BatchNorm2d(16)
        self.conv1b = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1b = nn.BatchNorm2d(16)
        self.conv1c = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1c = nn.BatchNorm2d(16)
        self.conv1d = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1d = nn.BatchNorm2d(16)
        self.conv1e = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1e = nn.BatchNorm2d(16)
        self.conv1f = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1f = nn.BatchNorm2d(16)
        
        self.conv1_2 = nn.Conv2d(16, 32, 3, stride=2, padding=1)
        self.batchnorm1_2 = nn.BatchNorm2d(32)
        self.bypass1_2 = nn.Conv2d(16, 32, 1, stride=2)
        self.conv2a = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2a = nn.BatchNorm2d(32)
        self.conv2b = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2b = nn.BatchNorm2d(32)
        self.conv2c = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2c = nn.BatchNorm2d(32)
        self.conv2d = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2d = nn.BatchNorm2d(32)
        self.conv2e = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2e = nn.BatchNorm2d(32)
        
        self.conv2_3 = nn.Conv2d(32, 64, 3, stride=2, padding=1)
        self.batchnorm2_3 = nn.BatchNorm2d(64)
        self.bypass2_3 = nn.Conv2d(32, 64, 1, stride=2)
        self.conv3a = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3a = nn.BatchNorm2d(64)
        self.conv3b = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3b = nn.BatchNorm2d(64)
        self.conv3c = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3c = nn.BatchNorm2d(64)
        self.conv3d = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3d = nn.BatchNorm2d(64)
        self.conv3e = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3e = nn.BatchNorm2d(64)
        self.fc = nn.Linear(64, 5)

    def forward(self, x):
        # Inital convolution
        out = self.batchnorm0(self.conv0(x))
        out = bypass = swish(out)
        # Block 1   (condense block layers into functions)
            # Layer 1
        out = self.batchnorm1a(self.conv1a(out))
        out = swish(out)
        out = self.batchnorm1b(self.conv1b(out))
        out = bypass = swish(out + bypass)
            # Layer 2
        out = self.batchnorm1c(self.conv1c(out))
        out = swish(out)
        out = self.batchnorm1d(self.conv1d(out))
        out = bypass = swish(out + bypass)
            # Layer 3
        out = self.batchnorm1e(self.conv1e(out))
        out = swish(out)
        out = self.batchnorm1f(self.conv1f(out))
        out = bypass = swish(out + bypass)
        # Block 2
            # Layer 1
        bypass = self.bypass1_2(bypass)
        out = self.batchnorm1_2(self.conv1_2(out))
        out = swish(out)
        out = self.batchnorm2a(self.conv2a(out))
        out = bypass = swish(out + bypass)
            # Layer 2
        out = self.batchnorm2b(self.conv2b(out))
        out = swish(out)
        out = self.batchnorm2c(self.conv2c(out))
        out = bypass = swish(out + bypass)
            # Layer 3
        out = self.batchnorm2d(self.conv2d(out))
        out = swish(out)
        out = self.batchnorm2e(self.conv2e(out))
        out = bypass = swish(out + bypass)
        # Block 3
            # Layer 1
        bypass = self.bypass2_3(bypass)
        out = self.batchnorm2_3(self.conv2_3(out))
        out = swish(out)
        out = self.batchnorm3a(self.conv3a(out))
        out = bypass = swish(out + bypass)
            # Layer 2
        out = self.batchnorm3b(self.conv3b(out))
        out = swish(out)
        out = self.batchnorm3c(self.conv3c(out))
        out = bypass = swish(out + bypass)
            # Layer 3
        out = self.batchnorm3d(self.conv3d(out))
        out = swish(out)
        out = self.batchnorm3e(self.conv3e(out))
        out = bypass = swish(out + bypass)
        
        # Global Average Pool to go from 8x8 -> 1x1 feature maps
        out = F.avg_pool2d(out, 8)
        
        # Fully Connected Layer
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        
        return out

# %%
#############################################
# sanity check for the correctness of Resnet20 architecture
dummy_input = torch.ones((1,3,32,32))
dummy_instance = Resnet20()
print(dummy_instance.forward(dummy_input))
total_params = 1
for p in dummy_instance.parameters():
    temp = 1
    for s in p.size():
        temp *= s
    total_params += temp
    #print(p.size())
print(f"Total Number of Parameters: {total_params}")
#############################################
# Out:
# tensor([[ 0.6145, -0.1300, -0.6888, -0.3672,  0.1317]],
#        grad_fn=<AddmmBackward0>)
# Total Number of Parameters: 272742

# %% [markdown]
# ## Set up preprocessing functions

# %%
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10 as torchCIFAR10

mean = (0.4914, 0.4822, 0.4465)
std = (0.2023, 0.1994, 0.2010)

# specify preprocessing function
transform_train = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std),
                                     transforms.RandomCrop(size=32, padding=4),
                                     transforms.RandomHorizontalFlip()])

transform_val = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std)])

transform_test = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std)])

transform_visulaizer = transforms.Compose([transforms.ToTensor()])

# %% [markdown]
# ## Set up dataset and dataloader

# %%
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader
from torch.utils.data import Subset
from torch.utils.data import ConcatDataset

DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 256
VAL_BATCH_SIZE = 100


# construct dataset
torch_train_set = torchCIFAR10(
    root=DATA_ROOT,
    train=True,
    transform=transform_train,
    download=True
)
all_testing = torchCIFAR10(
    root=DATA_ROOT,
    train=False,
    transform=transform_test,
    download=True
)

cifar5_train_labels = np.array(torch_train_set.targets)
cifar5_test_labels = np.array(all_testing.targets)
train_indices = []
all_test_indices = []
for i in [0,1,2,3,4]:
    train_indices += np.where(cifar5_train_labels == i)[0].tolist()
    all_test_indices += np.where(cifar5_test_labels == i)[0].tolist()
cifar5_train_set = Subset(torch_train_set, train_indices)
cifar5_test_set = Subset(all_testing, all_test_indices)

# construct dataloader
torch_train_loader = DataLoader(
    torch_train_set,
    batch_size = TRAIN_BATCH_SIZE,
    shuffle = True
)
torch_test_loader = DataLoader(
    all_testing,
    batch_size = 100
)
torch_val_loader = DataLoader(
    all_testing,
    batch_size = 100
)
cifar5_train_loader = DataLoader(
    cifar5_train_set,
    batch_size = TRAIN_BATCH_SIZE,
    shuffle = True
)
cifar5_test_loader = DataLoader(
    cifar5_test_set,
    batch_size = 100
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Instantiate Resnet-20 model and deploy it to GPU devices.

# %%
# specify the device for computation
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

cnn = Resnet20()
cnn.to(device)
print(next(cnn.parameters()).device)
# Out:
# cuda:0
# cuda:0

# %% [markdown]
# ## Set up the loss function and optimizer

# %%
import torch.nn as nn
import torch.optim as optim

# initial learning rate
WARMUP_LR = .01

# momentum for optimizer
MOMENTUM = 0.9

# L2 or L1 regularization strength
REG = 5e-4

# create loss function
criterion = nn.CrossEntropyLoss()

# Add optimizer
#optimizer for L2 regularization
optimizer = optim.SGD(cnn.parameters(), lr=WARMUP_LR, momentum=MOMENTUM, weight_decay=REG)
#optimizer for L1 regularization
#optimizer = optim.SGD(cnn.parameters(), lr=INITIAL_LR, momentum=MOMENTUM)

# %% [markdown]
# ## Start the training process.

# %%
EPOCHS = 150
CHECKPOINT_FOLDER = "./saved_model"
INITAL_LR = .005
DECAY_EPOCHS = 60
DECAY = .1
best_val_acc = 0
current_learning_rate = WARMUP_LR


print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    # handle the learning rate scheduler.
    if i == 5:
        current_learning_rate = INITAL_LR

    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    
    cnn.train()

    
    print("Epoch %d:" %i)
    total_examples = 0
    correct_examples = 0

    train_loss = 0
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(cifar5_train_loader):
        # copy inputs to device
        inputs = inputs.to(device) 
        targets = targets.type(torch.LongTensor)   #Cast target to long tensor type
        targets = targets.to(device)
        
        # compute the output and loss
        output = cnn.forward(inputs)
        #   loss function for L2 Regularization (reg is handled in the optimizer)
        loss = criterion(output, targets)   #Pass in softmax of final FC layer output for cross-entropy loss
        #   loss function for L1 Regularization
        #L1norm = sum(torch.sum(torch.abs(p)) for p in cnn.parameters())
        #loss = criterion(output, targets) + REG * L1norm
        if i == 0 and batch_idx < 3:
            print(f"Loss after {batch_idx} batches: {loss}")
        train_loss += loss
        
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        total_examples += targets.size()[0]
        batch_preds = torch.argmax(output, dim=1)
        correct_examples += (batch_preds == targets).int().sum().item()
                
    avg_loss = train_loss / len(torch_train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    # switch to eval mode
    cnn.eval()

    total_examples = 0
    correct_examples = 0
    
    val_loss = 0

    # disable gradient during validation, which can save GPU memory

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(cifar5_test_loader):
            if batch_idx < .5*len(cifar5_test_loader):  
                # copy inputs to device
                inputs = inputs.to(device)
                targets = targets.type(torch.LongTensor)
                targets = targets.to(device)

                # compute the output and loss
                output = cnn.forward(inputs)
                loss = criterion(output, targets)
                val_loss += loss
                
                # count the number of correctly predicted samples in the current batch
                total_examples += targets.size()[0]
                batch_preds = torch.argmax(output, dim=1)
                correct_examples += (batch_preds == targets).int().sum().item()

    avg_loss = val_loss / (.5*len(cifar5_test_loader))
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    # if avg_acc > best_val_acc:
    #     best_val_acc = avg_acc
    #     if not os.path.exists(CHECKPOINT_FOLDER):
    #        os.makedirs(CHECKPOINT_FOLDER)
    #     print("Saving ...")
    #     state = {'state_dict': cnn.state_dict(),
    #             'epoch': i,
    #             'lr': current_learning_rate}
    #     torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'cifar5_resnet20.pth'))
        
#     print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Loss after 0 batches: 1.7004594802856445
# Loss after 1 batches: 1.6927330493927002
# Loss after 2 batches: 1.6056878566741943
# Training loss: 0.5702, Training accuracy: 0.5096
# Validation loss: 0.7629, Validation accuracy: 0.6792
# Saving ...
# Epoch 1:
# Training loss: 0.4527, Training accuracy: 0.6292
# Validation loss: 0.6609, Validation accuracy: 0.7364
# Saving ...
# Epoch 2:
# Training loss: 0.3932, Training accuracy: 0.6897
# Validation loss: 1.0855, Validation accuracy: 0.5880
# Epoch 3:
# Training loss: 0.3463, Training accuracy: 0.7342
# Validation loss: 0.5730, Validation accuracy: 0.7836
# Saving ...
# Epoch 4:
# Training loss: 0.3141, Training accuracy: 0.7580
# Validation loss: 0.4765, Validation accuracy: 0.8300
# Saving ...
# Epoch 5:
# Training loss: 0.2798, Training accuracy: 0.7870
# Validation loss: 0.3587, Validation accuracy: 0.8732
# Saving ...
# Epoch 6:
# Training loss: 0.2539, Training accuracy: 0.8088
# Validation loss: 0.3652, Validation accuracy: 0.8688
# Epoch 7:
# Training loss: 0.2329, Training accuracy: 0.8242
# Validation loss: 0.3841, Validation accuracy: 0.8588
# Epoch 8:
# Training loss: 0.2158, Training accuracy: 0.8408
# Validation loss: 0.3233, Validation accuracy: 0.8748
# Saving ...
# Epoch 9:
# Training loss: 0.2051, Training accuracy: 0.8494
# Validation loss: 0.2797, Validation accuracy: 0.8936
# Saving ...
# Epoch 10:
# Training loss: 0.1921, Training accuracy: 0.8573
# Validation loss: 0.2852, Validation accuracy: 0.8992
# Saving ...
# Epoch 11:
# Training loss: 0.1819, Training accuracy: 0.8678
# Validation loss: 0.3077, Validation accuracy: 0.8804
# Epoch 12:
# Training loss: 0.1736, Training accuracy: 0.8743
# Validation loss: 0.2404, Validation accuracy: 0.9080
# Saving ...
# Epoch 13:
# Training loss: 0.1652, Training accuracy: 0.8805
# Validation loss: 0.2560, Validation accuracy: 0.9056
# Epoch 14:
# Training loss: 0.1568, Training accuracy: 0.8856
# Validation loss: 0.2754, Validation accuracy: 0.9004
# Epoch 15:
# Training loss: 0.1520, Training accuracy: 0.8903
# Validation loss: 0.4335, Validation accuracy: 0.8532
# Epoch 16:
# Training loss: 0.1465, Training accuracy: 0.8947
# Validation loss: 0.2160, Validation accuracy: 0.9152
# Saving ...
# Epoch 17:
# Training loss: 0.1417, Training accuracy: 0.8966
# Validation loss: 0.1871, Validation accuracy: 0.9364
# Saving ...
# Epoch 18:
# Training loss: 0.1347, Training accuracy: 0.9005
# Validation loss: 0.4451, Validation accuracy: 0.8644
# Epoch 19:
# Training loss: 0.1297, Training accuracy: 0.9064
# Validation loss: 0.2028, Validation accuracy: 0.9276
# Epoch 20:
# Training loss: 0.1266, Training accuracy: 0.9089
# Validation loss: 0.1653, Validation accuracy: 0.9404
# Saving ...
# Epoch 21:
# Training loss: 0.1228, Training accuracy: 0.9119
# Validation loss: 0.2290, Validation accuracy: 0.9176
# Epoch 22:
# Training loss: 0.1219, Training accuracy: 0.9101
# Validation loss: 0.2452, Validation accuracy: 0.9104
# Epoch 23:
# Training loss: 0.1157, Training accuracy: 0.9166
# Validation loss: 0.2765, Validation accuracy: 0.9024
# Epoch 24:
# Training loss: 0.1109, Training accuracy: 0.9194
# Validation loss: 0.2285, Validation accuracy: 0.9232
# Epoch 25:
# Training loss: 0.1074, Training accuracy: 0.9215
# Validation loss: 0.1992, Validation accuracy: 0.9308
# Epoch 26:
# Training loss: 0.1081, Training accuracy: 0.9220
# Validation loss: 0.3026, Validation accuracy: 0.8916
# Epoch 27:
# Training loss: 0.1035, Training accuracy: 0.9256
# Validation loss: 0.2130, Validation accuracy: 0.9204
# Epoch 28:
# Training loss: 0.0989, Training accuracy: 0.9284
# Validation loss: 0.2321, Validation accuracy: 0.9180
# Epoch 29:
# Training loss: 0.1010, Training accuracy: 0.9274
# Validation loss: 0.2434, Validation accuracy: 0.9116
# Epoch 30:
# Training loss: 0.0971, Training accuracy: 0.9304
# Validation loss: 0.2055, Validation accuracy: 0.9296
# Epoch 31:
# Training loss: 0.0921, Training accuracy: 0.9340
# Validation loss: 0.2621, Validation accuracy: 0.9156
# Epoch 32:
# Training loss: 0.0894, Training accuracy: 0.9362
# Validation loss: 0.2698, Validation accuracy: 0.9104
# Epoch 33:
# Training loss: 0.0847, Training accuracy: 0.9387
# Validation loss: 0.2077, Validation accuracy: 0.9280
# Epoch 34:
# Training loss: 0.0863, Training accuracy: 0.9371
# Validation loss: 0.3033, Validation accuracy: 0.9052
# Epoch 35:
# Training loss: 0.0838, Training accuracy: 0.9399
# Validation loss: 0.2178, Validation accuracy: 0.9320
# Epoch 36:
# Training loss: 0.0793, Training accuracy: 0.9432
# Validation loss: 0.2381, Validation accuracy: 0.9228
# Epoch 37:
# Training loss: 0.0797, Training accuracy: 0.9420
# Validation loss: 0.2461, Validation accuracy: 0.9184
# Epoch 38:
# Training loss: 0.0794, Training accuracy: 0.9426
# Validation loss: 0.1929, Validation accuracy: 0.9368
# Epoch 39:
# Training loss: 0.0762, Training accuracy: 0.9437
# Validation loss: 0.2631, Validation accuracy: 0.9132
# Epoch 40:
# Training loss: 0.0755, Training accuracy: 0.9452
# Validation loss: 0.2404, Validation accuracy: 0.9300
# Epoch 41:
# Training loss: 0.0791, Training accuracy: 0.9417
# Validation loss: 0.2261, Validation accuracy: 0.9268
# Epoch 42:
# Training loss: 0.0718, Training accuracy: 0.9486
# Validation loss: 0.3582, Validation accuracy: 0.8924
# Epoch 43:
# Training loss: 0.0704, Training accuracy: 0.9491
# Validation loss: 0.2092, Validation accuracy: 0.9344
# Epoch 44:
# Training loss: 0.0676, Training accuracy: 0.9508
# Validation loss: 0.2756, Validation accuracy: 0.9108
# Epoch 45:
# Training loss: 0.0683, Training accuracy: 0.9509
# Validation loss: 0.1911, Validation accuracy: 0.9396
# Epoch 46:
# Training loss: 0.0643, Training accuracy: 0.9540
# Validation loss: 0.2222, Validation accuracy: 0.9252
# Epoch 47:
# Training loss: 0.0650, Training accuracy: 0.9524
# Validation loss: 0.2369, Validation accuracy: 0.9264
# Epoch 48:
# Training loss: 0.0631, Training accuracy: 0.9540
# Validation loss: 0.2980, Validation accuracy: 0.9060
# Epoch 49:
# Training loss: 0.0619, Training accuracy: 0.9544
# Validation loss: 0.2889, Validation accuracy: 0.9140
# Epoch 50:
# Training loss: 0.0594, Training accuracy: 0.9573
# Validation loss: 0.2736, Validation accuracy: 0.9116
# Epoch 51:
# Training loss: 0.0576, Training accuracy: 0.9565
# Validation loss: 0.1840, Validation accuracy: 0.9420
# Saving ...
# Epoch 52:
# Training loss: 0.0586, Training accuracy: 0.9574
# Validation loss: 0.1868, Validation accuracy: 0.9392
# Epoch 53:
# Training loss: 0.0572, Training accuracy: 0.9590
# Validation loss: 0.1864, Validation accuracy: 0.9428
# Saving ...
# Epoch 54:
# Training loss: 0.0551, Training accuracy: 0.9604
# Validation loss: 0.1962, Validation accuracy: 0.9408
# Epoch 55:
# Training loss: 0.0567, Training accuracy: 0.9589
# Validation loss: 0.2369, Validation accuracy: 0.9284
# Epoch 56:
# Training loss: 0.0544, Training accuracy: 0.9589
# Validation loss: 0.3143, Validation accuracy: 0.9084
# Epoch 57:
# Training loss: 0.0568, Training accuracy: 0.9588
# Validation loss: 0.1967, Validation accuracy: 0.9380
# Epoch 58:
# Training loss: 0.0507, Training accuracy: 0.9638
# Validation loss: 0.2505, Validation accuracy: 0.9332
# Epoch 59:
# Training loss: 0.0502, Training accuracy: 0.9638
# Validation loss: 0.2046, Validation accuracy: 0.9424
# Current learning rate has decayed to 0.000500
# Epoch 60:
# Training loss: 0.0383, Training accuracy: 0.9738
# Validation loss: 0.1752, Validation accuracy: 0.9484
# Saving ...
# Epoch 61:
# Training loss: 0.0317, Training accuracy: 0.9798
# Validation loss: 0.1791, Validation accuracy: 0.9440
# Epoch 62:
# Training loss: 0.0286, Training accuracy: 0.9819
# Validation loss: 0.1767, Validation accuracy: 0.9468
# Epoch 63:
# Training loss: 0.0263, Training accuracy: 0.9831
# Validation loss: 0.1785, Validation accuracy: 0.9444
# Epoch 64:
# Training loss: 0.0251, Training accuracy: 0.9852
# Validation loss: 0.1727, Validation accuracy: 0.9476
# Epoch 65:
# Training loss: 0.0240, Training accuracy: 0.9854
# Validation loss: 0.1711, Validation accuracy: 0.9500
# Saving ...
# Epoch 66:
# Training loss: 0.0243, Training accuracy: 0.9859
# Validation loss: 0.1823, Validation accuracy: 0.9456
# Epoch 67:
# Training loss: 0.0223, Training accuracy: 0.9863
# Validation loss: 0.1833, Validation accuracy: 0.9448
# Epoch 68:
# Training loss: 0.0219, Training accuracy: 0.9874
# Validation loss: 0.1838, Validation accuracy: 0.9464
# Epoch 69:
# Training loss: 0.0215, Training accuracy: 0.9873
# Validation loss: 0.1823, Validation accuracy: 0.9468
# Epoch 70:
# Training loss: 0.0211, Training accuracy: 0.9875
# Validation loss: 0.1773, Validation accuracy: 0.9476
# Epoch 71:
# Training loss: 0.0219, Training accuracy: 0.9868
# Validation loss: 0.1923, Validation accuracy: 0.9444
# Epoch 72:
# Training loss: 0.0214, Training accuracy: 0.9871
# Validation loss: 0.1803, Validation accuracy: 0.9476
# Epoch 73:
# Training loss: 0.0202, Training accuracy: 0.9887
# Validation loss: 0.1920, Validation accuracy: 0.9444
# Epoch 74:
# Training loss: 0.0201, Training accuracy: 0.9884
# Validation loss: 0.1980, Validation accuracy: 0.9416
# Epoch 75:
# Training loss: 0.0204, Training accuracy: 0.9876
# Validation loss: 0.1877, Validation accuracy: 0.9472
# Epoch 76:
# Training loss: 0.0190, Training accuracy: 0.9897
# Validation loss: 0.1937, Validation accuracy: 0.9428
# Epoch 77:
# Training loss: 0.0192, Training accuracy: 0.9892
# Validation loss: 0.1918, Validation accuracy: 0.9436
# Epoch 78:
# Training loss: 0.0188, Training accuracy: 0.9889
# Validation loss: 0.1855, Validation accuracy: 0.9456
# Epoch 79:
# Training loss: 0.0190, Training accuracy: 0.9895
# Validation loss: 0.1967, Validation accuracy: 0.9428
# Epoch 80:
# Training loss: 0.0182, Training accuracy: 0.9897
# Validation loss: 0.1905, Validation accuracy: 0.9468
# Epoch 81:
# Training loss: 0.0170, Training accuracy: 0.9916
# Validation loss: 0.1894, Validation accuracy: 0.9460
# Epoch 82:
# Training loss: 0.0180, Training accuracy: 0.9898
# Validation loss: 0.1925, Validation accuracy: 0.9444
# Epoch 83:
# Training loss: 0.0178, Training accuracy: 0.9892
# Validation loss: 0.1923, Validation accuracy: 0.9444
# Epoch 84:
# Training loss: 0.0176, Training accuracy: 0.9907
# Validation loss: 0.1930, Validation accuracy: 0.9468
# Epoch 85:
# Training loss: 0.0180, Training accuracy: 0.9894
# Validation loss: 0.1863, Validation accuracy: 0.9472
# Epoch 86:
# Training loss: 0.0178, Training accuracy: 0.9895
# Validation loss: 0.1965, Validation accuracy: 0.9420
# Epoch 87:
# Training loss: 0.0171, Training accuracy: 0.9900
# Validation loss: 0.1926, Validation accuracy: 0.9452
# Epoch 88:
# Training loss: 0.0173, Training accuracy: 0.9906
# Validation loss: 0.2021, Validation accuracy: 0.9436
# Epoch 89:
# Training loss: 0.0170, Training accuracy: 0.9902
# Validation loss: 0.1938, Validation accuracy: 0.9444
# Epoch 90:
# Training loss: 0.0164, Training accuracy: 0.9912
# Validation loss: 0.1918, Validation accuracy: 0.9448
# Epoch 91:
# Training loss: 0.0163, Training accuracy: 0.9906
# Validation loss: 0.1906, Validation accuracy: 0.9456
# Epoch 92:
# Training loss: 0.0168, Training accuracy: 0.9905
# Validation loss: 0.1814, Validation accuracy: 0.9488
# Epoch 93:
# Training loss: 0.0159, Training accuracy: 0.9919
# Validation loss: 0.1863, Validation accuracy: 0.9452
# Epoch 94:
# Training loss: 0.0161, Training accuracy: 0.9912
# Validation loss: 0.1935, Validation accuracy: 0.9452
# Epoch 95:
# Training loss: 0.0158, Training accuracy: 0.9916
# Validation loss: 0.1940, Validation accuracy: 0.9460
# Epoch 96:
# Training loss: 0.0158, Training accuracy: 0.9914
# Validation loss: 0.1856, Validation accuracy: 0.9476
# Epoch 97:
# Training loss: 0.0158, Training accuracy: 0.9909
# Validation loss: 0.2001, Validation accuracy: 0.9416
# Epoch 98:
# Training loss: 0.0159, Training accuracy: 0.9906
# Validation loss: 0.1977, Validation accuracy: 0.9460
# Epoch 99:
# Training loss: 0.0150, Training accuracy: 0.9922
# Validation loss: 0.2032, Validation accuracy: 0.9424
# Epoch 100:
# Training loss: 0.0149, Training accuracy: 0.9919
# Validation loss: 0.2004, Validation accuracy: 0.9444
# Epoch 101:
# Training loss: 0.0146, Training accuracy: 0.9915
# Validation loss: 0.1928, Validation accuracy: 0.9460
# Epoch 102:
# Training loss: 0.0147, Training accuracy: 0.9920
# Validation loss: 0.2056, Validation accuracy: 0.9424
# Epoch 103:
# Training loss: 0.0151, Training accuracy: 0.9913
# Validation loss: 0.2024, Validation accuracy: 0.9432
# Epoch 104:
# Training loss: 0.0142, Training accuracy: 0.9928
# Validation loss: 0.1993, Validation accuracy: 0.9464
# Epoch 105:
# Training loss: 0.0146, Training accuracy: 0.9917
# Validation loss: 0.2046, Validation accuracy: 0.9444
# Epoch 106:
# Training loss: 0.0145, Training accuracy: 0.9926
# Validation loss: 0.2014, Validation accuracy: 0.9464
# Epoch 107:
# Training loss: 0.0143, Training accuracy: 0.9919
# Validation loss: 0.2021, Validation accuracy: 0.9424
# Epoch 108:
# Training loss: 0.0152, Training accuracy: 0.9922
# Validation loss: 0.1947, Validation accuracy: 0.9460
# Epoch 109:
# Training loss: 0.0144, Training accuracy: 0.9923
# Validation loss: 0.1997, Validation accuracy: 0.9456
# Epoch 110:
# Training loss: 0.0142, Training accuracy: 0.9926
# Validation loss: 0.1945, Validation accuracy: 0.9456
# Epoch 111:
# Training loss: 0.0132, Training accuracy: 0.9938
# Validation loss: 0.1975, Validation accuracy: 0.9456
# Epoch 112:
# Training loss: 0.0137, Training accuracy: 0.9927
# Validation loss: 0.2018, Validation accuracy: 0.9444
# Epoch 113:
# Training loss: 0.0143, Training accuracy: 0.9921
# Validation loss: 0.2001, Validation accuracy: 0.9452
# Epoch 114:
# Training loss: 0.0131, Training accuracy: 0.9936
# Validation loss: 0.2013, Validation accuracy: 0.9440
# Epoch 115:
# Training loss: 0.0138, Training accuracy: 0.9925
# Validation loss: 0.2010, Validation accuracy: 0.9444
# Epoch 116:
# Training loss: 0.0134, Training accuracy: 0.9924
# Validation loss: 0.2042, Validation accuracy: 0.9428
# Epoch 117:
# Training loss: 0.0129, Training accuracy: 0.9936
# Validation loss: 0.1943, Validation accuracy: 0.9440
# Epoch 118:
# Training loss: 0.0129, Training accuracy: 0.9940
# Validation loss: 0.2057, Validation accuracy: 0.9428
# Epoch 119:
# Training loss: 0.0124, Training accuracy: 0.9939
# Validation loss: 0.1971, Validation accuracy: 0.9460
# Current learning rate has decayed to 0.000050
# Epoch 120:
# Training loss: 0.0125, Training accuracy: 0.9935
# Validation loss: 0.1986, Validation accuracy: 0.9448
# Epoch 121:
# Training loss: 0.0127, Training accuracy: 0.9930
# Validation loss: 0.1952, Validation accuracy: 0.9464
# Epoch 122:
# Training loss: 0.0115, Training accuracy: 0.9947
# Validation loss: 0.1964, Validation accuracy: 0.9456
# Epoch 123:
# Training loss: 0.0124, Training accuracy: 0.9936
# Validation loss: 0.1957, Validation accuracy: 0.9460
# Epoch 124:
# Training loss: 0.0118, Training accuracy: 0.9939
# Validation loss: 0.1952, Validation accuracy: 0.9468
# Epoch 125:
# Training loss: 0.0122, Training accuracy: 0.9943
# Validation loss: 0.1998, Validation accuracy: 0.9456
# Epoch 126:
# Training loss: 0.0128, Training accuracy: 0.9928
# Validation loss: 0.2072, Validation accuracy: 0.9428
# Epoch 127:
# Training loss: 0.0123, Training accuracy: 0.9939
# Validation loss: 0.1946, Validation accuracy: 0.9464
# Epoch 128:
# Training loss: 0.0125, Training accuracy: 0.9938
# Validation loss: 0.1977, Validation accuracy: 0.9456
# Epoch 129:
# Training loss: 0.0123, Training accuracy: 0.9942
# Validation loss: 0.2065, Validation accuracy: 0.9440
# Epoch 130:
# Training loss: 0.0114, Training accuracy: 0.9949
# Validation loss: 0.1949, Validation accuracy: 0.9464
# Epoch 131:
# Training loss: 0.0124, Training accuracy: 0.9939
# Validation loss: 0.1954, Validation accuracy: 0.9460
# Epoch 132:
# Training loss: 0.0120, Training accuracy: 0.9944
# Validation loss: 0.1957, Validation accuracy: 0.9468
# Epoch 133:
# Training loss: 0.0117, Training accuracy: 0.9940
# Validation loss: 0.2051, Validation accuracy: 0.9432
# Epoch 134:
# Training loss: 0.0128, Training accuracy: 0.9932
# Validation loss: 0.1984, Validation accuracy: 0.9464
# Epoch 135:
# Training loss: 0.0115, Training accuracy: 0.9945
# Validation loss: 0.1893, Validation accuracy: 0.9488
# Epoch 136:
# Training loss: 0.0122, Training accuracy: 0.9940
# Validation loss: 0.2021, Validation accuracy: 0.9444
# Epoch 137:
# Training loss: 0.0125, Training accuracy: 0.9936
# Validation loss: 0.1985, Validation accuracy: 0.9464
# Epoch 138:
# Training loss: 0.0120, Training accuracy: 0.9941
# Validation loss: 0.2047, Validation accuracy: 0.9444
# Epoch 139:
# Training loss: 0.0123, Training accuracy: 0.9936
# Validation loss: 0.2020, Validation accuracy: 0.9448
# Epoch 140:
# Training loss: 0.0126, Training accuracy: 0.9937
# Validation loss: 0.1955, Validation accuracy: 0.9472
# Epoch 141:
# Training loss: 0.0115, Training accuracy: 0.9943
# Validation loss: 0.2032, Validation accuracy: 0.9432
# Epoch 142:
# Training loss: 0.0121, Training accuracy: 0.9934
# Validation loss: 0.2011, Validation accuracy: 0.9460
# Epoch 143:
# Training loss: 0.0120, Training accuracy: 0.9940
# Validation loss: 0.1905, Validation accuracy: 0.9476
# Epoch 144:
# Training loss: 0.0124, Training accuracy: 0.9939
# Validation loss: 0.1999, Validation accuracy: 0.9448
# Epoch 145:
# Training loss: 0.0123, Training accuracy: 0.9936
# Validation loss: 0.2011, Validation accuracy: 0.9448
# Epoch 146:
# Training loss: 0.0119, Training accuracy: 0.9942
# Validation loss: 0.2043, Validation accuracy: 0.9428
# Epoch 147:
# Training loss: 0.0119, Training accuracy: 0.9939
# Validation loss: 0.2012, Validation accuracy: 0.9460
# Epoch 148:
# Training loss: 0.0123, Training accuracy: 0.9937
# Validation loss: 0.1975, Validation accuracy: 0.9464
# Epoch 149:
# Training loss: 0.0124, Training accuracy: 0.9931
# Validation loss: 0.2008, Validation accuracy: 0.9440
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9500

# %% [markdown]
# ### Find max softmax statistics for in-distribution testing examples

# %%
cnn = Resnet20().to(device)
cnn.load_state_dict(torch.load("saved_model/cifar5_resnet20.pth")["state_dict"])
cnn.eval()

total_examples = 0
correct_examples = 0
val_loss = 0 
corr_max_softs = []
fals_max_softs = []
with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(cifar5_test_loader):
        if batch_idx > (.5*len(cifar5_test_loader)):
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.type(torch.LongTensor)
            targets = targets.to(device)
            # compute the output and loss
            output = cnn.forward(inputs)
            softmax = F.softmax(output, dim=1)
            loss = criterion(output, targets)
            val_loss += loss
            # count the number of correctly predicted samples in the current batch
            total_examples += targets.size()[0]
            batch_preds = torch.argmax(output, dim=1)
            correct_mask = (batch_preds == targets)
            correct_examples += correct_mask.int().sum().item()

            soft_batch_preds = torch.argmax(softmax, dim=1)
            for i in range(len(correct_mask)):
                if correct_mask[i]:
                    corr_max_softs.append(softmax[i][soft_batch_preds[i]].item())
                else:
                    fals_max_softs.append(softmax[i][soft_batch_preds[i]].item())

print(correct_examples/total_examples)
# Out:
# 0.8975

# %% [markdown]
# #### ROC Curve to show if softmax can be used to show misclassifications of in-distribution samples

# %%
import numpy as np
# true positive here is defined as correctly classifying a prediction as erroneous
def plot_roc(false_softs, true_softs, title = "ROC Curve", show_95TPR = True, show_OPT = False):
    TPRs = []     #  true positive rates
    FPRs = []     # false positive rates
    AUROC = []    # will contain the AUROC approximation segments
    opt = {"thresh":-1, "diff":-1, "FPR":-1, "TPR":-1}
    FPR_at_TPR95 = -1
    closest_TPR_to95 = -1
    prev_FPR = 0
    ct95 = 1
    for i in np.sort(np.concatenate((np.linspace(0, .8, 1000), np.linspace(.8,1,3000)))):
        TPR = sum(false_softs < i)/len(false_softs)
        FPR = sum(true_softs < i)/len(true_softs)
        AUROC.append((FPR-prev_FPR)*TPR)
        prev_FPR = FPR
        dis_from_95 = .95-TPR
        if dis_from_95 < ct95:
            ct95 = dis_from_95
            FPR_at_TPR95 = FPR
            closest_TPR_to95 = TPR
        # if round(TPR,2) == .95:
        #     FPR_at_TPR95 = FPR
        TPRs.append(TPR)
        FPRs.append(FPR)
        if TPR-FPR > opt["diff"]:
            opt["thresh"], opt["diff"], opt["FPR"], opt["TPR"]  = i, TPR-FPR, FPR, TPR
    plt.plot(FPRs, TPRs, 'm')
    plt.plot([0,1], [0,1], "k--", linewidth=.5)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(title)
    if show_95TPR:
        plt.plot(FPR_at_TPR95, closest_TPR_to95, 'X', ms=11, label=f"FPR@95TPR: {round(FPR_at_TPR95,3)}")
    if show_OPT:
        plt.plot(opt["FPR"], opt["TPR"], 'X', ms=11, label=f"OPT Thresh: {round(opt['thresh'],3)}")
        print(opt)
    plt.legend()
    plt.show()
    print(f"AUROC: {sum(AUROC)}")

# %%
plot_roc(fals_max_softs, corr_max_softs, title="ROC Curve\n (TP = correctly classifying erroneous prediction as erroneous)")
# Out:
# AUROC: 0.8650044160608736

# %% [markdown]
# # OOD Detection on CIFAR-100

# %%
from torchvision.datasets import CIFAR100

cifar100_set = CIFAR100(
    root=DATA_ROOT,
    train=False,
    transform=transform_test,
    download=True
)

cifar100_loader = DataLoader(
    cifar100_set
)
# Out:
# Files already downloaded and verified

# %%
OOD_softs = []
with torch.no_grad():
    for i, (img, target) in enumerate(cifar100_loader):
        img = img.to(device)
        target = target.type(torch.LongTensor)
        target = target.to(device)

        output = cnn.forward(img)
        softmax = F.softmax(output, dim=1)
        OOD_softs.append(softmax[0][torch.argmax(softmax)].item())
        batch_pred = torch.argmax(output, dim=1)
        if i%1000 == 0:
            print(f"{i}/{len(cifar100_loader)}")
            
InD_softs = fals_max_softs + corr_max_softs
# Out:
# 0/10000
# 1000/10000
# 2000/10000
# 3000/10000
# 4000/10000
# 5000/10000
# 6000/10000
# 7000/10000
# 8000/10000
# 9000/10000

# %%
plot_roc(OOD_softs, InD_softs)
# Out:
# AUROC: 0.7680048750000001

# %%
#unseen_lbls = list(np.linspace(0,99,100))
# with torch.no_grad():
#     for i, (img, target) in enumerate(cifar100_loader):
#         #if target.item() in unseen_lbls:
#         if target.item() == 81:
#             plt.imshow(torch.permute(torch.squeeze(img), (1,2,0)).cpu().numpy())
#             plt.show()
#             print(target.item())
#             #unseen_lbls.remove(target.item())
