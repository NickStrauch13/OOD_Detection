# %%
from google.colab import drive
drive.mount('/content/drive')

import os
pwd = "/content/drive/MyDrive/ECE661FinalProj_OODD"
os.chdir(pwd)
# Out:
# Mounted at /content/drive

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
def swish(x):
    return x/(1+torch.exp(-x))

# %%
# define the Resnet20 mode;
class Resnet20(nn.Module):
    def __init__(self):
        super(Resnet20, self).__init__()
        self.conv0 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.batchnorm0 = nn.BatchNorm2d(16)
        
        self.conv1a = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1a = nn.BatchNorm2d(16)
        self.conv1b = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1b = nn.BatchNorm2d(16)
        self.conv1c = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1c = nn.BatchNorm2d(16)
        self.conv1d = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1d = nn.BatchNorm2d(16)
        self.conv1e = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1e = nn.BatchNorm2d(16)
        self.conv1f = nn.Conv2d(16, 16, 3, padding=1)
        self.batchnorm1f = nn.BatchNorm2d(16)
        
        self.conv1_2 = nn.Conv2d(16, 32, 3, stride=2, padding=1)
        self.batchnorm1_2 = nn.BatchNorm2d(32)
        self.bypass1_2 = nn.Conv2d(16, 32, 1, stride=2)
        self.conv2a = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2a = nn.BatchNorm2d(32)
        self.conv2b = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2b = nn.BatchNorm2d(32)
        self.conv2c = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2c = nn.BatchNorm2d(32)
        self.conv2d = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2d = nn.BatchNorm2d(32)
        self.conv2e = nn.Conv2d(32, 32, 3, padding=1)
        self.batchnorm2e = nn.BatchNorm2d(32)
        
        self.conv2_3 = nn.Conv2d(32, 64, 3, stride=2, padding=1)
        self.batchnorm2_3 = nn.BatchNorm2d(64)
        self.bypass2_3 = nn.Conv2d(32, 64, 1, stride=2)
        self.conv3a = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3a = nn.BatchNorm2d(64)
        self.conv3b = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3b = nn.BatchNorm2d(64)
        self.conv3c = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3c = nn.BatchNorm2d(64)
        self.conv3d = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3d = nn.BatchNorm2d(64)
        self.conv3e = nn.Conv2d(64, 64, 3, padding=1)
        self.batchnorm3e = nn.BatchNorm2d(64)
        self.fc = nn.Linear(64, 5)

    def forward(self, x):
        # Inital convolution
        out = self.batchnorm0(self.conv0(x))
        out = bypass = swish(out)
        # Block 1   (condense block layers into functions)
            # Layer 1
        out = self.batchnorm1a(self.conv1a(out))
        out = swish(out)
        out = self.batchnorm1b(self.conv1b(out))
        out = bypass = swish(out + bypass)
            # Layer 2
        out = self.batchnorm1c(self.conv1c(out))
        out = swish(out)
        out = self.batchnorm1d(self.conv1d(out))
        out = bypass = swish(out + bypass)
            # Layer 3
        out = self.batchnorm1e(self.conv1e(out))
        out = swish(out)
        out = self.batchnorm1f(self.conv1f(out))
        out = bypass = swish(out + bypass)
        # Block 2
            # Layer 1
        bypass = self.bypass1_2(bypass)
        out = self.batchnorm1_2(self.conv1_2(out))
        out = swish(out)
        out = self.batchnorm2a(self.conv2a(out))
        out = bypass = swish(out + bypass)
            # Layer 2
        out = self.batchnorm2b(self.conv2b(out))
        out = swish(out)
        out = self.batchnorm2c(self.conv2c(out))
        out = bypass = swish(out + bypass)
            # Layer 3
        out = self.batchnorm2d(self.conv2d(out))
        out = swish(out)
        out = self.batchnorm2e(self.conv2e(out))
        out = bypass = swish(out + bypass)
        # Block 3
            # Layer 1
        bypass = self.bypass2_3(bypass)
        out = self.batchnorm2_3(self.conv2_3(out))
        out = swish(out)
        out = self.batchnorm3a(self.conv3a(out))
        out = bypass = swish(out + bypass)
            # Layer 2
        out = self.batchnorm3b(self.conv3b(out))
        out = swish(out)
        out = self.batchnorm3c(self.conv3c(out))
        out = bypass = swish(out + bypass)
            # Layer 3
        out = self.batchnorm3d(self.conv3d(out))
        out = swish(out)
        out = self.batchnorm3e(self.conv3e(out))
        out = bypass = swish(out + bypass)
        
        # Global Average Pool to go from 8x8 -> 1x1 feature maps
        out = F.avg_pool2d(out, 8)
        
        # Fully Connected Layer
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        
        return out

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10 as torchCIFAR10

#############################################
mean = (0.4914, 0.4822, 0.4465)
std = (0.2023, 0.1994, 0.2010)


# specify preprocessing function
transform_train = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std),
                                     transforms.RandomCrop(size=32, padding=4),
                                     transforms.RandomHorizontalFlip()])

transform_val = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std)])

transform_test = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std)])


#############################################

# %%
# a few arguments, do NOT change these
import numpy as np
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader
from torch.utils.data import Subset

DATA_ROOT = "./data"
inTRAIN_BATCH_SIZE = 128
outBATCH_SIZE = 256
VAL_BATCH_SIZE = 100


# construct dataset
torch_train_set = torchCIFAR10(
    root=DATA_ROOT,
    train=True,
    transform=transform_train,
    download=True
)
all_testing = torchCIFAR10(
    root=DATA_ROOT,
    train=False,
    transform=transform_test,
    download=True
)

cifar5_train_labels = np.array(torch_train_set.targets)
cifar5_test_labels = np.array(all_testing.targets)
train_indices = []
all_test_indices = []
for i in [0,1,2,3,4]:
    train_indices += np.where(cifar5_train_labels == i)[0].tolist()
    all_test_indices += np.where(cifar5_test_labels == i)[0].tolist()

cifar5_train_set = Subset(torch_train_set, train_indices)
cifar5_test_set = Subset(all_testing, all_test_indices)

# construct dataloader
torch_train_loader = DataLoader(
    torch_train_set,
    batch_size = inTRAIN_BATCH_SIZE,
    shuffle = True
)

torch_test_loader = DataLoader(
    all_testing,
    batch_size = 100
)

cifar5_train_loader = DataLoader(
    cifar5_train_set,
    batch_size = inTRAIN_BATCH_SIZE,
    shuffle = True
)

cifar5_test_loader = DataLoader(
    cifar5_test_set,
    batch_size = VAL_BATCH_SIZE
)

from torchvision.datasets import CIFAR100

cifar100_set = CIFAR100(
    root=DATA_ROOT,
    train=False,
    transform=transform_test,
    download=True
)

cifar100_loader = DataLoader(
    cifar100_set,
    shuffle=True,
    batch_size = outBATCH_SIZE
)

cifar100_labels = np.array(cifar100_set.targets)
train_indices = []
test_indices = []

for i in range(50):
    train_indices += np.where(cifar100_labels == i)[0].tolist()

cifar50_set = Subset(cifar100_set, train_indices)

cifar50_loader = DataLoader(
    cifar50_set,
    shuffle=True,
    batch_size = outBATCH_SIZE
)

cifar20_indices = []
for i in range(20):
    cifar20_indices += np.where(cifar100_labels == i)[0].tolist()

cifar20_set = Subset(cifar100_set, cifar20_indices)

cifar20_loader = DataLoader(
    cifar20_set,
    shuffle=True,
    batch_size = outBATCH_SIZE
)

cifar5_indices = []
for i in range(5):
    cifar5_indices += np.where(cifar100_labels == i)[0].tolist()

cifar5_set = Subset(cifar100_set, cifar5_indices)

cifar5_loader = DataLoader(
    cifar5_set,
    shuffle=True,
    batch_size = outBATCH_SIZE
)

cifar1_indices = []
for i in range(1):
    cifar1_indices += np.where(cifar100_labels == i)[0].tolist()

cifar1_set = Subset(cifar100_set, cifar1_indices)

cifar1_loader = DataLoader(
    cifar1_set,
    shuffle=True,
    batch_size = outBATCH_SIZE
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# #TRAINING

# %%
from torch.cuda.random import device_count
# specify the device for computation
#############################################
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
cnn = Resnet20()
cnn.to(device)
print(device)
#############################################
# Out:
# cuda:0

# %%
import torch.nn as nn
import torch.optim as optim

WARMUP_LR = .01
MOMENTUM = 0.9
REG = 5e-4
optimizer = optim.SGD(cnn.parameters(), lr=WARMUP_LR, momentum=MOMENTUM, weight_decay=REG)

EPOCHS = 150
CHECKPOINT_FOLDER = "./saved_model"

INITAL_LR = .1
DECAY_EPOCHS = 60
DECAY = .1

m_in = -23
m_out = -5

# %%
def train(in_loader, out_loader, PTH, energy=False):
    avg_loss = 0
    best_val_acc = 0
    current_learning_rate = WARMUP_LR
    #Learning rate scheduler
    for i in tqdm(range(EPOCHS)):
        if i == 5:
          current_learning_rate = INITAL_LR
        if i % DECAY_EPOCHS == 0 and i != 0:
          current_learning_rate = current_learning_rate * DECAY
          for param_group in optimizer.param_groups:
              param_group['lr'] = current_learning_rate
          
        cnn.train()
        
        print(f"Epoch: {i}/{EPOCHS}")
        for in_set, out_set in zip(in_loader, out_loader):
            
            data = torch.cat((in_set[0], out_set[0]), 0)
            target = in_set[1].type(torch.LongTensor)
            data, target = data.to(device), target.to(device)
            
            # Forward Pass
            x = cnn.forward(data)
            # print(x.shape)
            loss = F.cross_entropy(x[:len(in_set[0])], target)
            # cross-entropy from softmax distribution to uniform distribution
            if energy:
              Ec_out = -torch.logsumexp(x[len(in_set[0]):], dim=1)
              Ec_in = -torch.logsumexp(x[:len(in_set[0])], dim=1)
              loss += 0.1*(torch.pow(F.relu(Ec_in- m_in), 2).mean() + torch.pow(F.relu(m_out-Ec_out), 2).mean())

            else:
              loss += 0.5 * -(x[len(in_set[0]):].mean(1) - torch.logsumexp(x[len(in_set[0]):], dim=1)).mean()
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            avg_loss = .8 * avg_loss + float(loss) * 0.2
      
        print(f"avg training loss: {avg_loss}")
      
        
        cnn.eval()

        total_examples = 0
        correct_examples = 0

        val_loss = 0

        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(cifar5_test_loader):
              if batch_idx < 0.5*len(cifar5_test_loader):
                # copy inputs to device
                inputs = inputs.to(device)
                targets = targets.type(torch.LongTensor)
                targets = targets.to(device)

                # compute the output and loss
                output = cnn.forward(inputs)
                loss = F.cross_entropy(output, targets)
                val_loss += loss

                # count the number of correctly predicted samples in the current batch
                total_examples += targets.size()[0]
                batch_preds = torch.argmax(output, dim=1)
                correct_examples += (batch_preds == targets).int().sum().item()

        avg_loss = val_loss / (0.50* len(cifar5_test_loader))
        avg_acc = correct_examples / total_examples
        print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
        
        #save the model checkpoint
        if avg_acc > best_val_acc:
            best_val_acc = avg_acc
            if not os.path.exists(CHECKPOINT_FOLDER):
               os.makedirs(CHECKPOINT_FOLDER)
            print("Saving ...")
            state = {'state_dict': cnn.state_dict(),
                    'epoch': i,
                    'lr': current_learning_rate}
            torch.save(state, os.path.join(CHECKPOINT_FOLDER, PTH))

# %%
PTH = 'cifar5_cifar20_OE_resnet.pth'
in_loader = cifar5_train_loader
out_loader = cifar20_loader

train(in_loader, out_loader, PTH)
# Out:
# <ipython-input-92-eec71a9dc797>:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(EPOCHS)):
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch: 0/150
# avg training loss: 2.0040906467694093
# Validation loss: 1.7000, Validation accuracy: 0.0000
# Epoch: 1/150
# avg training loss: 2.1908652782440186
# Validation loss: 1.7812, Validation accuracy: 0.0000
# Epoch: 2/150
# avg training loss: 2.1241514682769775
# Validation loss: 1.8532, Validation accuracy: 0.1420
# Saving ...
# Epoch: 3/150
# avg training loss: 2.1117119789123535
# Validation loss: 1.8275, Validation accuracy: 0.2456
# Saving ...
# Epoch: 4/150
# avg training loss: 2.0383660793304443
# Validation loss: 1.4956, Validation accuracy: 0.3700
# Saving ...
# Epoch: 5/150
# avg training loss: 1.988984227180481
# Validation loss: 1.1574, Validation accuracy: 0.5396
# Saving ...
# Epoch: 6/150
# avg training loss: 1.8977431058883667
# Validation loss: 0.8501, Validation accuracy: 0.6512
# Saving ...
# Epoch: 7/150
# avg training loss: 1.874411702156067
# Validation loss: 0.8695, Validation accuracy: 0.7060
# Saving ...
# Epoch: 8/150
# avg training loss: 1.8183658123016357
# Validation loss: 0.8919, Validation accuracy: 0.6420
# Epoch: 9/150
# avg training loss: 1.828997015953064
# Validation loss: 0.8756, Validation accuracy: 0.6704
# Epoch: 10/150
# avg training loss: 1.7907698154449463
# Validation loss: 0.9244, Validation accuracy: 0.6492
# Epoch: 11/150
# avg training loss: 1.8350334167480469
# Validation loss: 0.9219, Validation accuracy: 0.6392
# Epoch: 12/150
# avg training loss: 1.8246599435806274
# Validation loss: 0.7890, Validation accuracy: 0.6864
# Epoch: 13/150
# avg training loss: 1.7395164966583252
# Validation loss: 0.7162, Validation accuracy: 0.7504
# Saving ...
# Epoch: 14/150
# avg training loss: 1.761584758758545
# Validation loss: 1.0962, Validation accuracy: 0.5408
# Epoch: 15/150
# avg training loss: 1.7883424758911133
# Validation loss: 0.8066, Validation accuracy: 0.7304
# Epoch: 16/150
# avg training loss: 1.748197078704834
# Validation loss: 0.8352, Validation accuracy: 0.6504
# Epoch: 17/150
# avg training loss: 1.715855598449707
# Validation loss: 0.9139, Validation accuracy: 0.6468
# Epoch: 18/150
# avg training loss: 1.7542271614074707
# Validation loss: 0.7214, Validation accuracy: 0.7196
# Epoch: 19/150
# avg training loss: 1.703498125076294
# Validation loss: 0.7344, Validation accuracy: 0.7400
# Epoch: 20/150
# avg training loss: 1.7130458354949951
# Validation loss: 0.7064, Validation accuracy: 0.7560
# Saving ...
# Epoch: 21/150
# avg training loss: 1.7010273933410645
# Validation loss: 0.7089, Validation accuracy: 0.7180
# Epoch: 22/150
# avg training loss: 1.6719547510147095
# Validation loss: 0.8814, Validation accuracy: 0.6460
# Epoch: 23/150
# avg training loss: 1.7098417282104492
# Validation loss: 0.6539, Validation accuracy: 0.7512
# Epoch: 24/150
# avg training loss: 1.6410391330718994
# Validation loss: 0.9132, Validation accuracy: 0.6700
# Epoch: 25/150
# avg training loss: 1.6824963092803955
# Validation loss: 0.6343, Validation accuracy: 0.7824
# Saving ...
# Epoch: 26/150
# avg training loss: 1.6423503160476685
# Validation loss: 0.8024, Validation accuracy: 0.7312
# Epoch: 27/150
# avg training loss: 1.6511831283569336
# Validation loss: 0.7284, Validation accuracy: 0.7596
# Epoch: 28/150
# avg training loss: 1.6405370235443115
# Validation loss: 0.8008, Validation accuracy: 0.7384
# Epoch: 29/150
# avg training loss: 1.614233136177063
# Validation loss: 0.5854, Validation accuracy: 0.7808
# Epoch: 30/150
# avg training loss: 1.6192078590393066
# Validation loss: 0.6373, Validation accuracy: 0.7856
# Saving ...
# Epoch: 31/150
# avg training loss: 1.5886733531951904
# Validation loss: 0.9525, Validation accuracy: 0.6260
# Epoch: 32/150
# avg training loss: 1.6384837627410889
# Validation loss: 0.8555, Validation accuracy: 0.6708
# Epoch: 33/150
# avg training loss: 1.6478291749954224
# Validation loss: 0.7362, Validation accuracy: 0.7308
# Epoch: 34/150
# avg training loss: 1.5960569381713867
# Validation loss: 0.5913, Validation accuracy: 0.7856
# Epoch: 35/150
# avg training loss: 1.5918879508972168
# Validation loss: 0.6221, Validation accuracy: 0.7880
# Saving ...
# Epoch: 36/150
# avg training loss: 1.5513248443603516
# Validation loss: 0.5011, Validation accuracy: 0.8388
# Saving ...
# Epoch: 37/150
# avg training loss: 1.513695478439331
# Validation loss: 0.6374, Validation accuracy: 0.7772
# Epoch: 38/150
# avg training loss: 1.5528039932250977
# Validation loss: 0.9097, Validation accuracy: 0.6932
# Epoch: 39/150
# avg training loss: 1.6164813041687012
# Validation loss: 0.7199, Validation accuracy: 0.7808
# Epoch: 40/150
# avg training loss: 1.561995267868042
# Validation loss: 0.5600, Validation accuracy: 0.8188
# Epoch: 41/150
# avg training loss: 1.506561040878296
# Validation loss: 0.6647, Validation accuracy: 0.7900
# Epoch: 42/150
# avg training loss: 1.5197410583496094
# Validation loss: 0.6533, Validation accuracy: 0.7896
# Epoch: 43/150
# avg training loss: 1.5709792375564575
# Validation loss: 0.6224, Validation accuracy: 0.8080
# Epoch: 44/150
# avg training loss: 1.5284998416900635
# Validation loss: 0.6278, Validation accuracy: 0.7748
# Epoch: 45/150
# avg training loss: 1.5375547409057617
# Validation loss: 0.6441, Validation accuracy: 0.7692
# Epoch: 46/150
# avg training loss: 1.5099499225616455
# Validation loss: 0.5811, Validation accuracy: 0.8160
# Epoch: 47/150
# avg training loss: 1.5024924278259277
# Validation loss: 0.7178, Validation accuracy: 0.7888
# Epoch: 48/150
# avg training loss: 1.5373237133026123
# Validation loss: 0.6751, Validation accuracy: 0.7852
# Epoch: 49/150
# avg training loss: 1.4808311462402344
# Validation loss: 0.7116, Validation accuracy: 0.7576
# Epoch: 50/150
# avg training loss: 1.4822263717651367
# Validation loss: 0.6168, Validation accuracy: 0.7948
# Epoch: 51/150
# avg training loss: 1.4974164962768555
# Validation loss: 0.6125, Validation accuracy: 0.7924
# Epoch: 52/150
# avg training loss: 1.490129828453064
# Validation loss: 0.6538, Validation accuracy: 0.7876
# Epoch: 53/150
# avg training loss: 1.4944754838943481
# Validation loss: 0.5565, Validation accuracy: 0.8304
# Epoch: 54/150
# avg training loss: 1.4624836444854736
# Validation loss: 0.5783, Validation accuracy: 0.8292
# Epoch: 55/150
# avg training loss: 1.4342154264450073
# Validation loss: 0.6710, Validation accuracy: 0.7720
# Epoch: 56/150
# avg training loss: 1.4774341583251953
# Validation loss: 0.6485, Validation accuracy: 0.7780
# Epoch: 57/150
# avg training loss: 1.4824944734573364
# Validation loss: 0.7107, Validation accuracy: 0.7348
# Epoch: 58/150
# avg training loss: 1.4978828430175781
# Validation loss: 0.4911, Validation accuracy: 0.8264
# Epoch: 59/150
# avg training loss: 1.4168550968170166
# Validation loss: 0.6694, Validation accuracy: 0.7896
# Epoch: 60/150
# avg training loss: 1.4905446767807007
# Validation loss: 0.6091, Validation accuracy: 0.8116
# Epoch: 61/150
# avg training loss: 1.4260005950927734
# Validation loss: 0.6849, Validation accuracy: 0.7932
# Epoch: 62/150
# avg training loss: 1.504202127456665
# Validation loss: 0.5654, Validation accuracy: 0.8516
# Saving ...
# Epoch: 63/150
# avg training loss: 1.4034743309020996
# Validation loss: 0.7014, Validation accuracy: 0.7544
# Epoch: 64/150
# avg training loss: 1.4373353719711304
# Validation loss: 0.5520, Validation accuracy: 0.8164
# Epoch: 65/150
# avg training loss: 1.416288137435913
# Validation loss: 0.7443, Validation accuracy: 0.7652
# Epoch: 66/150
# avg training loss: 1.4576454162597656
# Validation loss: 0.5548, Validation accuracy: 0.8568
# Saving ...
# Epoch: 67/150
# avg training loss: 1.3857818841934204
# Validation loss: 0.5760, Validation accuracy: 0.8508
# Epoch: 68/150
# avg training loss: 1.4020063877105713
# Validation loss: 0.7311, Validation accuracy: 0.7576
# Epoch: 69/150
# avg training loss: 1.395066738128662
# Validation loss: 0.6236, Validation accuracy: 0.8116
# Epoch: 70/150
# avg training loss: 1.3809983730316162
# Validation loss: 0.6063, Validation accuracy: 0.8156
# Epoch: 71/150
# avg training loss: 1.3937060832977295
# Validation loss: 0.5507, Validation accuracy: 0.8448
# Epoch: 72/150
# avg training loss: 1.3343220949172974
# Validation loss: 0.5568, Validation accuracy: 0.8540
# Epoch: 73/150
# avg training loss: 1.379101276397705
# Validation loss: 0.7061, Validation accuracy: 0.7652
# Epoch: 74/150
# avg training loss: 1.374549150466919
# Validation loss: 0.6867, Validation accuracy: 0.7972
# Epoch: 75/150
# avg training loss: 1.385056734085083
# Validation loss: 0.5447, Validation accuracy: 0.8320
# Epoch: 76/150
# avg training loss: 1.3490651845932007
# Validation loss: 0.5826, Validation accuracy: 0.8264
# Epoch: 77/150
# avg training loss: 1.3794565200805664
# Validation loss: 0.6305, Validation accuracy: 0.8004
# Epoch: 78/150
# avg training loss: 1.3562722206115723
# Validation loss: 0.6062, Validation accuracy: 0.8432
# Epoch: 79/150
# avg training loss: 1.336021900177002
# Validation loss: 0.5864, Validation accuracy: 0.8180
# Epoch: 80/150
# avg training loss: 1.3799097537994385
# Validation loss: 0.5892, Validation accuracy: 0.8540
# Epoch: 81/150
# avg training loss: 1.3665541410446167
# Validation loss: 0.5934, Validation accuracy: 0.8340
# Epoch: 82/150
# avg training loss: 1.3643008470535278
# Validation loss: 0.6142, Validation accuracy: 0.7976
# Epoch: 83/150
# avg training loss: 1.3627382516860962
# Validation loss: 0.5587, Validation accuracy: 0.8072
# Epoch: 84/150
# avg training loss: 1.3026492595672607
# Validation loss: 0.6637, Validation accuracy: 0.7892
# Epoch: 85/150
# avg training loss: 1.3483991622924805
# Validation loss: 0.6502, Validation accuracy: 0.8272
# Epoch: 86/150
# avg training loss: 1.358959436416626
# Validation loss: 0.6421, Validation accuracy: 0.8416
# Epoch: 87/150
# avg training loss: 1.3457175493240356
# Validation loss: 0.7482, Validation accuracy: 0.7368
# Epoch: 88/150
# avg training loss: 1.3737215995788574
# Validation loss: 0.6387, Validation accuracy: 0.8160
# Epoch: 89/150
# avg training loss: 1.3208208084106445
# Validation loss: 0.6124, Validation accuracy: 0.8288
# Epoch: 90/150
# avg training loss: 1.3350622653961182
# Validation loss: 0.6083, Validation accuracy: 0.8292
# Epoch: 91/150
# avg training loss: 1.2988206148147583
# Validation loss: 0.5903, Validation accuracy: 0.8568
# Epoch: 92/150
# avg training loss: 1.2850596904754639
# Validation loss: 0.6344, Validation accuracy: 0.8008
# Epoch: 93/150
# avg training loss: 1.2817803621292114
# Validation loss: 0.6069, Validation accuracy: 0.8344
# Epoch: 94/150
# avg training loss: 1.3263496160507202
# Validation loss: 0.5811, Validation accuracy: 0.7992
# Epoch: 95/150
# avg training loss: 1.3342363834381104
# Validation loss: 0.7837, Validation accuracy: 0.7684
# Epoch: 96/150
# avg training loss: 1.3603553771972656
# Validation loss: 0.5908, Validation accuracy: 0.8348
# Epoch: 97/150
# avg training loss: 1.3003554344177246
# Validation loss: 0.5875, Validation accuracy: 0.8344
# Epoch: 98/150
# avg training loss: 1.3187024593353271
# Validation loss: 0.7280, Validation accuracy: 0.7836
# Epoch: 99/150
# avg training loss: 1.3078413009643555
# Validation loss: 0.5462, Validation accuracy: 0.8788
# Saving ...
# Epoch: 100/150
# avg training loss: 1.277717113494873
# Validation loss: 0.6098, Validation accuracy: 0.8228
# Epoch: 101/150
# avg training loss: 1.2711946964263916
# Validation loss: 0.6406, Validation accuracy: 0.8208
# Epoch: 102/150
# avg training loss: 1.3038370609283447
# Validation loss: 0.6154, Validation accuracy: 0.7876
# Epoch: 103/150
# avg training loss: 1.2923780679702759
# Validation loss: 0.5128, Validation accuracy: 0.8652
# Epoch: 104/150
# avg training loss: 1.276400089263916
# Validation loss: 0.5956, Validation accuracy: 0.8300
# Epoch: 105/150
# avg training loss: 1.2828576564788818
# Validation loss: 0.7715, Validation accuracy: 0.7692
# Epoch: 106/150
# avg training loss: 1.2653851509094238
# Validation loss: 0.7389, Validation accuracy: 0.7236
# Epoch: 107/150
# avg training loss: 1.3311442136764526
# Validation loss: 0.8093, Validation accuracy: 0.7532
# Epoch: 108/150
# avg training loss: 1.315528392791748
# Validation loss: 0.7453, Validation accuracy: 0.7988
# Epoch: 109/150
# avg training loss: 1.3323967456817627
# Validation loss: 0.5598, Validation accuracy: 0.8540
# Epoch: 110/150
# avg training loss: 1.249032735824585
# Validation loss: 0.6649, Validation accuracy: 0.8424
# Epoch: 111/150
# avg training loss: 1.2387936115264893
# Validation loss: 0.5532, Validation accuracy: 0.8684
# Epoch: 112/150
# avg training loss: 1.2233728170394897
# Validation loss: 0.6111, Validation accuracy: 0.8208
# Epoch: 113/150
# avg training loss: 1.2722338438034058
# Validation loss: 0.7205, Validation accuracy: 0.8180
# Epoch: 114/150
# avg training loss: 1.2371618747711182
# Validation loss: 0.6354, Validation accuracy: 0.8236
# Epoch: 115/150
# avg training loss: 1.232508659362793
# Validation loss: 0.7005, Validation accuracy: 0.8148
# Epoch: 116/150
# avg training loss: 1.224677324295044
# Validation loss: 0.5937, Validation accuracy: 0.8408
# Epoch: 117/150
# avg training loss: 1.2613446712493896
# Validation loss: 0.5305, Validation accuracy: 0.8500
# Epoch: 118/150
# avg training loss: 1.2315330505371094
# Validation loss: 0.6151, Validation accuracy: 0.8252
# Epoch: 119/150
# avg training loss: 1.2395610809326172
# Validation loss: 0.5754, Validation accuracy: 0.8436
# Epoch: 120/150
# avg training loss: 1.2425075769424438
# Validation loss: 0.5538, Validation accuracy: 0.8668
# Epoch: 121/150
# avg training loss: 1.2082240581512451
# Validation loss: 0.5598, Validation accuracy: 0.8688
# Epoch: 122/150
# avg training loss: 1.231309413909912
# Validation loss: 0.5635, Validation accuracy: 0.8640
# Epoch: 123/150
# avg training loss: 1.163955569267273
# Validation loss: 0.5737, Validation accuracy: 0.8648
# Epoch: 124/150
# avg training loss: 1.1920478343963623
# Validation loss: 0.5958, Validation accuracy: 0.8624
# Epoch: 125/150
# avg training loss: 1.1435959339141846
# Validation loss: 0.6072, Validation accuracy: 0.8636
# Epoch: 126/150
# avg training loss: 1.1424654722213745
# Validation loss: 0.6227, Validation accuracy: 0.8624
# Epoch: 127/150
# avg training loss: 1.1644552946090698
# Validation loss: 0.6114, Validation accuracy: 0.8696
# Epoch: 128/150
# avg training loss: 1.192483901977539
# Validation loss: 0.5768, Validation accuracy: 0.8756
# Epoch: 129/150
# avg training loss: 1.1185076236724854
# Validation loss: 0.5619, Validation accuracy: 0.8712
# Epoch: 130/150
# avg training loss: 1.147179126739502
# Validation loss: 0.5377, Validation accuracy: 0.8760
# Epoch: 131/150
# avg training loss: 1.1205923557281494
# Validation loss: 0.5542, Validation accuracy: 0.8724
# Epoch: 132/150
# avg training loss: 1.1814420223236084
# Validation loss: 0.5622, Validation accuracy: 0.8660
# Epoch: 133/150
# avg training loss: 1.1639419794082642
# Validation loss: 0.5738, Validation accuracy: 0.8660
# Epoch: 134/150
# avg training loss: 1.1650017499923706
# Validation loss: 0.5900, Validation accuracy: 0.8632
# Epoch: 135/150
# avg training loss: 1.1353687047958374
# Validation loss: 0.5712, Validation accuracy: 0.8652
# Epoch: 136/150
# avg training loss: 1.105397343635559
# Validation loss: 0.5564, Validation accuracy: 0.8688
# Epoch: 137/150
# avg training loss: 1.1389522552490234
# Validation loss: 0.5489, Validation accuracy: 0.8720
# Epoch: 138/150
# avg training loss: 1.1476612091064453
# Validation loss: 0.5453, Validation accuracy: 0.8732
# Epoch: 139/150
# avg training loss: 1.133545160293579
# Validation loss: 0.5581, Validation accuracy: 0.8664
# Epoch: 140/150
# avg training loss: 1.1205488443374634
# Validation loss: 0.5674, Validation accuracy: 0.8640
# Epoch: 141/150
# avg training loss: 1.1133233308792114
# Validation loss: 0.5664, Validation accuracy: 0.8696
# Epoch: 142/150
# avg training loss: 1.1261142492294312
# Validation loss: 0.5643, Validation accuracy: 0.8732
# Epoch: 143/150
# avg training loss: 1.129532814025879
# Validation loss: 0.5624, Validation accuracy: 0.8604
# Epoch: 144/150
# avg training loss: 1.1408929824829102
# Validation loss: 0.5676, Validation accuracy: 0.8604
# Epoch: 145/150
# avg training loss: 1.1357080936431885
# Validation loss: 0.5764, Validation accuracy: 0.8628
# Epoch: 146/150
# avg training loss: 1.1066462993621826
# Validation loss: 0.5537, Validation accuracy: 0.8792
# Saving ...
# Epoch: 147/150
# avg training loss: 1.1064825057983398
# Validation loss: 0.5477, Validation accuracy: 0.8812
# Saving ...
# Epoch: 148/150
# avg training loss: 1.1126105785369873
# Validation loss: 0.5263, Validation accuracy: 0.8832
# Saving ...
# Epoch: 149/150
# avg training loss: 1.1330666542053223
# Validation loss: 0.5464, Validation accuracy: 0.8700

# %%
state = {'state_dict': cnn.state_dict()}
torch.save(state, os.path.join(CHECKPOINT_FOLDER, PTH))

# %% [markdown]
# #TESTING

# %%
PTH = 'cifer5_cifar100_OE_resnet.pth'
cnn = Resnet20().to(device)
cnn.load_state_dict(torch.load(os.path.join(CHECKPOINT_FOLDER, PTH))["state_dict"])
cnn.eval()
# Out:
# Resnet20(
#   (conv0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1a): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1a): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1b): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1b): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1c): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1c): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1d): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1e): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1e): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1f): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1f): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (batchnorm1_2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bypass1_2): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2))
#   (conv2a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm2a): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm2b): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2c): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm2c): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2d): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2e): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm2e): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2_3): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (batchnorm2_3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bypass2_3): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#   (conv3a): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm3a): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm3b): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3c): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm3c): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3d): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm3d): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3e): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm3e): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=64, out_features=5, bias=True)
# )

# %%
def energy_fun(cnn_output, T):
  return -T* torch.logsumexp(cnn_output / T, dim=1)

# %%
total_examples = 0
correct_examples = 0
val_loss = 0 
energy_corr_score = []
energy_fals_score = []

softmax_corr_score = []
softmax_fals_score = []

T = 1
with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(cifar5_test_loader):
      if batch_idx > 0.50*len(cifar5_test_loader):
          # copy inputs to device
          inputs = inputs.to(device)
          targets = targets.type(torch.LongTensor)
          targets = targets.to(device)
          # compute the output and loss
          output = cnn.forward(inputs)
          softmax = F.softmax(output, dim=1)
          energy = energy_fun(output, T)

          # count the number of correctly predicted samples in the current batch
          total_examples += targets.size()[0]
          batch_preds = torch.argmax(output, dim=1)
          correct_mask = (batch_preds == targets)
          correct_examples += correct_mask.int().sum().item()
          soft_batch_preds = torch.argmax(softmax, dim=1)
          for i in range(len(correct_mask)):
              if correct_mask[i]:
                  energy_corr_score.append(energy[i].item())
                  softmax_corr_score.append(softmax[i][soft_batch_preds[i]].item())
              else:
                  energy_fals_score.append(energy[i].item())
                  softmax_fals_score.append(softmax[i][soft_batch_preds[i]].item())

print(correct_examples/total_examples)
energy_InD_score = energy_fals_score + energy_corr_score
softmax_InD_score = softmax_corr_score  + softmax_fals_score
# Out:
# 0.76125

# %%
import numpy as np
# true positive here is defined as correctly classifying a prediction as erroneous
def plot_roc(false_softs, true_softs, title = "ROC Curve", show_95TPR = True, show_OPT = False):
    TPRs = []     #  true positive rates
    FPRs = []     # false positive rates
    AUROC = []    # will contain the AUROC approximation segments
    opt = {"thresh":-1, "diff":-1, "FPR":-1, "TPR":-1}
    FPR_at_TPR95 = -1
    closest_TPR_to95 = -1
    prev_FPR = 0
    ct95 = 1
    min_val = min(min(false_softs), min(true_softs))
    max_val = max(max(false_softs), max(true_softs))
    for i in tqdm(np.linspace(min_val, max_val, 1000)):
        FPR = sum(false_softs < i)/len(false_softs)
        TPR = sum(true_softs < i)/len(true_softs)
        AUROC.append((FPR-prev_FPR)*TPR)
        prev_FPR = FPR
        dis_from_95 = .95-TPR
        if abs(dis_from_95) < ct95:
            ct95 = dis_from_95
            FPR_at_TPR95 = FPR
            closest_TPR_to95 = TPR
        # if round(TPR,2) == .95:
        #     FPR_at_TPR95 = FPR
        TPRs.append(TPR)
        FPRs.append(FPR)
        if TPR-FPR > opt["diff"]:
            opt["thresh"], opt["diff"], opt["FPR"], opt["TPR"]  = i, TPR-FPR, FPR, TPR
    plt.plot(FPRs, TPRs, 'm')
    plt.plot([0,1], [0,1], "k--", linewidth=.5)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(title)
    if show_95TPR:
        plt.plot(FPR_at_TPR95, closest_TPR_to95, 'X', ms=11, label=f"FPR@95TPR: {round(FPR_at_TPR95,3)}")
    if show_OPT:
        plt.plot(opt["FPR"], opt["TPR"], 'X', ms=11, label=f"OPT Thresh: {round(opt['thresh'],3)}")
        print(opt)
    plt.legend()
    plt.show()
    print(f"AUROC: {sum(AUROC)}")

# %%
plot_roc(softmax_corr_score, softmax_fals_score, title="ROC Curve\n (TP = correctly classifying erroneous prediction as erroneous)")
# Out:
# <ipython-input-28-4938b0975def>:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(np.linspace(min_val, max_val, 1000)):
#   0%|          | 0/1000 [00:00<?, ?it/s]
# AUROC: 0.8872001175711451

# %%
from torchvision.datasets import CIFAR100

cifar100_set = CIFAR100(
    root=DATA_ROOT,
    train=False,
    transform=transform_test,
    download=True
)

cifar100_loader = DataLoader(
    cifar100_set
)
# Out:
# Files already downloaded and verified

# %%
def find_OOD_scores(OOD_loader):
  energy_OOD_score = []
  softmax_OOD_score = []
  with torch.no_grad():
      for i, (img, target) in tqdm(enumerate(OOD_loader)):
          img = img.to(device)
          target = target.type(torch.LongTensor)
          target = target.to(device)

          output = cnn.forward(img)
          # energy = energy_fun(output, T)
          softmax = F.softmax(output, dim=1)
          # print(softmax.shape)
          # print(energy.shape)
          # energy_OOD_score.append(energy.item())
          softmax_OOD_score.append(softmax[0][torch.argmax(softmax)].item())
          batch_pred = torch.argmax(output, dim=1)
  return softmax_OOD_score

# %%
softmax_OOD_score = find_OOD_scores(cifar100_loader)
# Out:
# <ipython-input-47-0d3cbe53d610>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i, (img, target) in tqdm(enumerate(OOD_loader)):
# 0it [00:00, ?it/s]
# torch.Size([256, 10])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-a120b832ca70> in <module>
# ----> 1 softmax_OOD_score = find_OOD_scores(cifar100_loader)
#
# <ipython-input-47-0d3cbe53d610> in find_OOD_scores(OOD_loader)
#      14           # print(energy.shape)
#      15           # energy_OOD_score.append(energy.item())
# ---> 16           softmax_OOD_score.append(softmax[0][torch.argmax(softmax)].item())
#      17           batch_pred = torch.argmax(output, dim=1)
#      18   return softmax_OOD_score
#
# IndexError: index 292 is out of bounds for dimension 0 with size 10

# %%
plot_roc(softmax_OOD_score, softmax_InD_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-e976c7d5a7d4> in <module>
# ----> 1 plot_roc(softmax_OOD_score, softmax_InD_score)
#
# NameError: name 'softmax_OOD_score' is not defined

# %%
from torchvision.datasets import SVHN

SVHN_Data = SVHN(
    root='./data/',
    transform=transform_test,
    download=True
)
SVHN_loader = DataLoader(
    SVHN_Data
)
# Out:
# Using downloaded and verified file: ./data/train_32x32.mat

# %%
svhnOOD_score = find_OOD_scores(SVHN_loader)
# Out:
# <ipython-input-69-bca9f90026e1>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i, (img, target) in tqdm(enumerate(OOD_loader)):
# 0it [00:00, ?it/s]

# %%
plot_roc(softmax_InD_score,svhnOOD_score, title="Cifar5 Cifar100 ROC Sotmax Thresholding")
# Out:
# <ipython-input-73-4938b0975def>:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(np.linspace(min_val, max_val, 1000)):
#   0%|          | 0/1000 [00:00<?, ?it/s]
# AUROC: 0.8151783617947768
